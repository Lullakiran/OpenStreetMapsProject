# %%
import xml.etree.ElementTree as ET
import codecs
import json
import re

# %%
def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()

input_ankara = "ankara_turkey.osm"
root = get_root(input_ankara)

# %%
def count_tags(root,tag):
    tag_count = 0
    for i in root.findall(tag):
        tag_count += 1
    return tag_count


def count_users(root):
    user = set()
    for i in root.findall('node') :
        try:
            user.add(i.attrib['user'])
        except:
            pass
    for i in root.findall('way'):
        try:
            user.add(i.attrib['user'])
        except:
            pass
    return  len(user)

# %%
counts = {}
for i in ['node', 'way', 'relation' ]:
    counts[i] = count_tags(root,i)
counts['user'] = count_users(root)
print counts
# Out:
# {'node': 638467, 'relation': 220, 'user': 500, 'way': 92056}

# %%
def extend_abbrevations(address):
    extended_address = ''
    abbrevations = { 'Cd.': 'Caddesi', 'Cad.':'Caddesi', 'Cd':'Caddesi', 'Sk.':'Sokak', 
                    'Mah.':'Mahallesi', 'Blv.':u'Bulvar\u0131', 'Bul.':u'Bulvar\u0131'}
    for word in address.split():
        
        try:
            extended_address += abbrevations[word] + ' ' #check whether this word is an abbrevation 
            # print "before cleaning: ", address, "\t after cleaning: ", extended_address
        except:
            extended_address += word+ ' '
    return extended_address[:-1] #discard the last character, whitespace

# %%
def extend_abbrevations_split_by_multiple(address):
    extended_address = ''
    abbrevations = { 'Cd.': 'Caddesi', 'Cad.':'Caddesi', 'Cd':'Caddesi', 'Sk.':'Sokak', 
                    'Mah.':'Mahallesi', 'Blv.':u'Bulvar\u0131', 'Bul.':u'Bulvar\u0131'}
    splitted_address = re.findall(r'[^,;\s]+', address)
    for word in splitted_address:
        print word
        try:
            extended_address += abbrevations[word] + ' ' #check whether this word is an abbrevation 
            # print "before cleaning: ", address, "\t after cleaning: ", extended_address
        except:
            extended_address += word+ ' '
    return extended_address[:-1] #discard the last character, whitespace

# %%
def capitalize_turkish_title(address):
     
    capitalized_address = ''
    connectors = ['ve', 'de', 'ile', 'ki', 'ya', 'ya da'] #this words should not be capitalized
    for word in address.split(' ',';'):
         
        capitalized_address += word + ' ' if word in connectors else word.title()+' '
        
     
    if address.islower():
        print 'before capitalization: ', address, '\t after capitalization: ', capitalized_address

    return capitalized_address[:-1]  #discard the last character, whitespace

# %%
def correct_postcode(postcode):  #postcodes must start with 06, and must be 5 digits long
    if len(postcode) != 5: # found short postcodes like 0600, 65 in the data
        print 'postcode length is wrong', postcode
        return None
    elif re.match(r'(06\d\d\d)',postcode)  == None: #check if all digits (i.e. not Esma 3 Sokak) and starts with 06
        print 'invalid postcode', postcode
        return None
    return postcode

# %% [markdown]
# ## Problems ##
# 1) Abbreviated street, avenue names (e.g. 'Cad.', 'Cd', 'Sk.')
#
# 2) Capitalization problems (e.g. 'cad.' , u'kalekap\u0131s\u0131' , 'ANKARA')
#
# 3) Postcodes should consist of exactly 5 digits, and should start with 06.

# %%
global k 
k=0

# %%
us_ct = 0
uniq_users = set()
def get_value(element, attribute): #inspired from http://goo.gl/1n3xO5, assigns value if the field exists
    try:
        return element.attrib[attribute]
    except:
        return None
    
def shape_element(element):
    global uniq_users
    node = {}
    lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
    problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

    if element.tag == "node" or element.tag == "way" :
        node['type'] = element.tag
        node['id'] =  element.attrib['id']
        
        node['created'] = { 'timestamp' : get_value(element,'timestamp'),
                            'version': get_value(element,'version'),
                            'changeset': get_value(element,'changeset'), 
                            'user':get_value(element,'user'), 
                            'uid': get_value(element,'uid')}
        node['visible'] =  get_value(element,'visible')
        
        try:    
            node['pos'] = [float(get_value(element,'lat')), float(get_value(element,'lon'))]
        except:
            pass
        
        try:
            uniq_users.add(get_value(element,'user'))
        except:
            pass
        
        
        for i in element:
        
            if element.tag=="way":
                try:
                    node.setdefault('node_refs',[]).append(i.attrib['ref'])        #http://stackoverflow.com/questions/12905999/python-dict-how-to-create-key-or-append-an-element-to-key
                except:
                    pass
            
            try:
                if "addr" in i.attrib['k']:
                    addr, field = lower_colon.match(i.attrib['k']).group().split(':') 
                    length = len(lower_colon.match(i.attrib['k']).group().split(':'))
                    v = i.attrib['v']

                    if  length <= 2 and addr=='addr' and problemchars.match(v) == None:   
                        if field == 'postcode':
                            v = correct_postcode(v)
                                                    
                        #fix capitalizations, and abbrevations
                        
                        node.setdefault('address',{}).update({ field: capitalize_turkish_title(extend_abbrevations(v))  }) 
                else:
                     
                    if i.attrib['k'] != 'type': #some entries have <tag k = "type" v=...>
                        node[i.attrib['k']] = i.attrib['v']
                        #node[i.attrib['k']] =  capitalize_turkish_title(extend_abbrevations(i.attrib['v']))
                    
            except:
                pass
            
        return node
    else:
  
        return None

# %%
def process_map(file_in, pretty = False):
    k = 0
 
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el  = shape_element(element)
            if k > 122150:
                pass
            if el:
                k += 1
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    
    return data

# %%
clean_ankara = process_map("ankara_turkey.osm")
# Out:
# before capitalization:  city 	 after capitalization:  City
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  country 	 after capitalization:  Country
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  wikipedia 	 after capitalization:  Wikipedia
# before capitalization:  aerodrome 	 after capitalization:  Aerodrome
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  town 	 after capitalization:  Town
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  town 	 after capitalization:  Town
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  toll_booth 	 after capitalization:  Toll_Booth
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  toll_booth 	 after capitalization:  Toll_Booth
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  town 	 after capitalization:  Town
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bump 	 after capitalization:  Bump
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  shell 	 after capitalization:  Shell
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  park 	 after capitalization:  Park
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  motorway_junction 	 after capitalization:  Motorway_Junction
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  monument 	 after capitalization:  Monument
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  electronics 	 after capitalization:  Electronics
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  cargo 	 after capitalization:  Cargo
# before capitalization:  soccer 	 after capitalization:  Soccer
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  dormitory 	 after capitalization:  Dormitory
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  market 	 after capitalization:  Market
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  fish 	 after capitalization:  Fish
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  hump 	 after capitalization:  Hump
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  government 	 after capitalization:  Government
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  international 	 after capitalization:  International
# before capitalization:  estate_agent 	 after capitalization:  Estate_Agent
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  residential 	 after capitalization:  Residential
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  broadcasting 	 after capitalization:  Broadcasting
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  sports 	 after capitalization:  Sports
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  kiosk 	 after capitalization:  Kiosk
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  candy 	 after capitalization:  Candy
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  turkish 	 after capitalization:  Turkish
# before capitalization:  tyres 	 after capitalization:  Tyres
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  minyon 	 after capitalization:  Minyon
# before capitalization:  jewelry 	 after capitalization:  Jewelry
# before capitalization:  jewelry 	 after capitalization:  Jewelry
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  ballroom 	 after capitalization:  Ballroom
# before capitalization:  bed 	 after capitalization:  Bed
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  herbs 	 after capitalization:  Herbs
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  hairdresser 	 after capitalization:  Hairdresser
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  notary 	 after capitalization:  Notary
# before capitalization:  notary 	 after capitalization:  Notary
# before capitalization:  telephone 	 after capitalization:  Telephone
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  chinese 	 after capitalization:  Chinese
# before capitalization:  http://www.quickchina.com.tr/ 	 after capitalization:  Http://Www.Quickchina.Com.Tr/
# before capitalization:  house_of_person 	 after capitalization:  House_Of_Person
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  no 	 after capitalization:  No
# before capitalization:  basketball 	 after capitalization:  Basketball
# before capitalization:  kiosk 	 after capitalization:  Kiosk
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  attaa 	 after capitalization:  Attaa
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  mall 	 after capitalization:  Mall
# before capitalization:  music 	 after capitalization:  Music
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  tennis 	 after capitalization:  Tennis
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  fine_dining 	 after capitalization:  Fine_Dining
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  hairdresser 	 after capitalization:  Hairdresser
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  hardware 	 after capitalization:  Hardware
# before capitalization:  stationery 	 after capitalization:  Stationery
# before capitalization:  hairdresser 	 after capitalization:  Hairdresser
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  post_office 	 after capitalization:  Post_Office
# before capitalization:  photo 	 after capitalization:  Photo
# before capitalization:  video 	 after capitalization:  Video
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  kebab 	 after capitalization:  Kebab
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  dry_cleaning 	 after capitalization:  Dry_Cleaning
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  organic 	 after capitalization:  Organic
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  post_office 	 after capitalization:  Post_Office
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  video 	 after capitalization:  Video
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  kiosk 	 after capitalization:  Kiosk
# before capitalization:  leather 	 after capitalization:  Leather
# before capitalization:  dairy 	 after capitalization:  Dairy
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  cinema 	 after capitalization:  Cinema
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  chocolate 	 after capitalization:  Chocolate
# before capitalization:  avea 	 after capitalization:  Avea
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  toys 	 after capitalization:  Toys
# before capitalization:  mall 	 after capitalization:  Mall
# before capitalization:  doctors 	 after capitalization:  Doctors
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  books 	 after capitalization:  Books
# before capitalization:  survey 	 after capitalization:  Survey
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  business 	 after capitalization:  Business
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  regional 	 after capitalization:  Regional
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  park 	 after capitalization:  Park
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  chocolate 	 after capitalization:  Chocolate
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  building 	 after capitalization:  Building
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  lake 	 after capitalization:  Lake
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  find tags 	 after capitalization:  Find Tags
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  park 	 after capitalization:  Park
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  http://www.cankaya-bld.gov.tr/ahlatlibel.asp 	 after capitalization:  Http://Www.Cankaya-Bld.Gov.Tr/Ahlatlibel.Asp
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  10pin 	 after capitalization:  10Pin
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  town 	 after capitalization:  Town
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  town 	 after capitalization:  Town
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_station 	 after capitalization:  Bus_Station
# before capitalization:  theatre 	 after capitalization:  Theatre
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  unknown 	 after capitalization:  Unknown
# before capitalization:  elizinn 	 after capitalization:  Elizinn
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  toys 	 after capitalization:  Toys
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  leather 	 after capitalization:  Leather
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  gymnastics 	 after capitalization:  Gymnastics
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  museum 	 after capitalization:  Museum
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  market 	 after capitalization:  Market
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  computer 	 after capitalization:  Computer
# before capitalization:  leather 	 after capitalization:  Leather
# before capitalization:  mado 	 after capitalization:  Mado
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  leather 	 after capitalization:  Leather
# before capitalization:  bakery 	 after capitalization:  Bakery
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  yes, this edge is correct 	 after capitalization:  Yes, This Edge Is Correct
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  cargo 	 after capitalization:  Cargo
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  chinese 	 after capitalization:  Chinese
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  alcohol 	 after capitalization:  Alcohol
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  travel_agency 	 after capitalization:  Travel_Agency
# before capitalization:  casa 	 after capitalization:  Casa
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  hometextile 	 after capitalization:  Hometextile
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  bureau_de_change 	 after capitalization:  Bureau_De_Change
# before capitalization:  electronics 	 after capitalization:  Electronics
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  kiosk 	 after capitalization:  Kiosk
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  grocery 	 after capitalization:  Grocery
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  burger 	 after capitalization:  Burger
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  car 	 after capitalization:  Car
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  fashion 	 after capitalization:  Fashion
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  pub 	 after capitalization:  Pub
# before capitalization:  car_rental 	 after capitalization:  Car_Rental
# before capitalization:  car_rental 	 after capitalization:  Car_Rental
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  florist 	 after capitalization:  Florist
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  snacks 	 after capitalization:  Snacks
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  toys 	 after capitalization:  Toys
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  butcher 	 after capitalization:  Butcher
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  public_building 	 after capitalization:  Public_Building
# before capitalization:  post_office 	 after capitalization:  Post_Office
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  mall 	 after capitalization:  Mall
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  atm 	 after capitalization:  Atm
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  cargo 	 after capitalization:  Cargo
# before capitalization:  pharmacy 	 after capitalization:  Pharmacy
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  mall 	 after capitalization:  Mall
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  makkarna 	 after capitalization:  Makkarna
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  fast_food 	 after capitalization:  Fast_Food
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  furniture 	 after capitalization:  Furniture
# before capitalization:  traffic_signals 	 after capitalization:  Traffic_Signals
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bank 	 after capitalization:  Bank
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  theatre 	 after capitalization:  Theatre
# before capitalization:  theatre 	 after capitalization:  Theatre
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  bazaar 	 after capitalization:  Bazaar
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  http://www.medicine.ankara.edu.tr/ankarahastane/ 	 after capitalization:  Http://Www.Medicine.Ankara.Edu.Tr/Ankarahastane/
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  public_building 	 after capitalization:  Public_Building
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  http://ataturkhastanesi.gov.tr/ 	 after capitalization:  Http://Ataturkhastanesi.Gov.Tr/
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  guest_house 	 after capitalization:  Guest_House
# before capitalization:  barracks 	 after capitalization:  Barracks
# before capitalization:  skating 	 after capitalization:  Skating
# before capitalization:  police 	 after capitalization:  Police
# before capitalization:  limited 	 after capitalization:  Limited
# before capitalization:  theatre 	 after capitalization:  Theatre
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  embassy 	 after capitalization:  Embassy
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  patisserie 	 after capitalization:  Patisserie
# before capitalization:  bazaar 	 after capitalization:  Bazaar
# before capitalization:  marketplace 	 after capitalization:  Marketplace
# before capitalization:  technology 	 after capitalization:  Technology
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  parking 	 after capitalization:  Parking
# ...
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  peak 	 after capitalization:  Peak
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  village 	 after capitalization:  Village
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  communication 	 after capitalization:  Communication
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  tower 	 after capitalization:  Tower
# before capitalization:  bing 	 after capitalization:  Bing
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  lift_gate 	 after capitalization:  Lift_Gate
# before capitalization:  free 	 after capitalization:  Free
# before capitalization:  university 	 after capitalization:  University
# before capitalization:  cafe 	 after capitalization:  Cafe
# before capitalization:  coffee_shop 	 after capitalization:  Coffee_Shop
# before capitalization:  emergency 	 after capitalization:  Emergency
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  stationery 	 after capitalization:  Stationery
# before capitalization:  stationery 	 after capitalization:  Stationery
# before capitalization:  university 	 after capitalization:  University
# before capitalization:  vending_machine 	 after capitalization:  Vending_Machine
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  uncontrolled 	 after capitalization:  Uncontrolled
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  local 	 after capitalization:  Local
# before capitalization:  bench 	 after capitalization:  Bench
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  main 	 after capitalization:  Main
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  neighbourhood 	 after capitalization:  Neighbourhood
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  http://www.divan.com.tr 	 after capitalization:  Http://Www.Divan.Com.Tr
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  hospital 	 after capitalization:  Hospital
# before capitalization:  yes 	 after capitalization:  Yes
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  supermarket 	 after capitalization:  Supermarket
# before capitalization:  hamlet 	 after capitalization:  Hamlet
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  crossing 	 after capitalization:  Crossing
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  suburb 	 after capitalization:  Suburb
# before capitalization:  school 	 after capitalization:  School
# before capitalization:  taxi 	 after capitalization:  Taxi
# before capitalization:  hamlet 	 after capitalization:  Hamlet
# before capitalization:  post_office 	 after capitalization:  Post_Office
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  bus_stop 	 after capitalization:  Bus_Stop
# before capitalization:  fuel 	 after capitalization:  Fuel
# before capitalization:  hotel 	 after capitalization:  Hotel
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  stop_position 	 after capitalization:  Stop_Position
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  station 	 after capitalization:  Station
# before capitalization:  subway_entrance 	 after capitalization:  Subway_Entrance
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  drinking_water 	 after capitalization:  Drinking_Water
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  hamlet 	 after capitalization:  Hamlet
# before capitalization:  hamlet 	 after capitalization:  Hamlet
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  bbq 	 after capitalization:  Bbq
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  restaurant 	 after capitalization:  Restaurant
# before capitalization:  parking 	 after capitalization:  Parking
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  shelter 	 after capitalization:  Shelter
# before capitalization:  turning_circle 	 after capitalization:  Turning_Circle
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:  mini_roundabout 	 after capitalization:  Mini_Roundabout
# before capitalization:

# %%
ct=0
for i in clean_ankara:
    if ct >310:
        break
    
 
    try:
        #if 'ABD' in i['name']:
        #    print i['name'].encode('utf-8')
        # i['address']
        ct += 1
        if i['address']['city'].islower():
            print i['address']['city']
        #    ct +=1 
        #if i['type']=='node' or i['type']=='way':
                 
    except:
        pass
print ct
# Out:
# 311

# %%
def capitalize_turkish_title(word):
    capitalized_word = ''
    connectors = ['ve', 'de', 'ile', 'ki', 'ya', 'ya da']
    for w in word.split():
        capitalized_word += w + ' ' if w in connectors else w.title()+' '
    
    return capitalized_word[:-1]  #discard the last space

# %%
capitalize_turkish_title('sda saf Esam ve')
# Out:
# 'Sda Saf Esam ve'

# %%
extend_abbrevations("Hipodrom Cad.;Talat Paşa Bulvarı")
# Out:
# Hipodrom
# Cad.;Talat
# Paşa
# Bulvarı
# 'Hipodrom Cad.;Talat Pa\xc5\x9fa Bulvar\xc4\xb1'

# %%
"Hipodrom Cad.;Talat Paşa Bulvarı".replace(";"split("\s;")
# Out:
# ['Hipodrom Cad.;Talat Pa\xc5\x9fa Bulvar\xc4\xb1']

# %%
str = 'a,,b,c,'
re.findall(r'[^,;\s]+', str)
# Out:
# ['Hipodrom', 'Cad.', 'Talat', 'Pa\xc5\x9fa', 'Bulvar\xc4\xb1']

# %%
extend_abbrevations_split_by_multiple("Hipodrom Cad.;Talat Paşa Bulvarı")
# Out:
# Hipodrom
# Cad.
# Talat
# Paşa
# Bulvarı
# 'Hipodrom Caddesi Talat Pa\xc5\x9fa Bulvar\xc4\xb1'
